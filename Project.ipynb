# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the dataset
df = pd.read_excel('Absenteeism_at_work.xls')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
pd.set_option('display.max.columns',30)
pd.set_option('display.max.rows',800)

# %%
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# 5     3                  23                 7                6        1
# 6    10                  22                 7                6        1
# 7    20                  23                 7                6        1
# 8    14                  19                 7                2        1
# 9     1                  22                 7                2        1
# 10   20                   1                 7                2        1
# 11   20                   1                 7                3        1
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
#Checking null values
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 34

# %%
df[df.duplicated()]
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 16    3                  23                 7                6        1
# 68   34                  23                10                3        4
# 88   28                  23                11                4        4
# 109  10                  22                12                4        4
# 127  34                  27                 1                2        2
# 128  34                  27                 1                3        2
# 131  34                  27                 1                4        2
# 132  27                  23                 1                5        2
# 133  34                  27                 1                5        2
# 305   5                  23                10                2        4
# 351   3                  28                12                6        4
# 376   3                  27                 2                4        2
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
#Dropping duplicated values
df = df[~df.duplicated()]

# %%
df.shape
# Out:
# (706, 21)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Reason for absence, Month of absence, Day of the week, Seasons, Transportation expense, Distance from Residence to Work, Service time, Age, Work load Average/day , Hit target, Disciplinary failure, Education, Son, Social drinker, Social smoker, Pet, Weight, Height, Body mass index, Absenteeism time in hours]
# Index: []

# %%
#Checking outliers
def boxplot(x):
    sns.boxplot(x,data = df)
for i in df.columns:
    boxplot(i)
    plt.show()

# %%
#No Outliers

# %%
def distplot(x):
    sns.distplot(df[x])
for i in df.columns:
    distplot(i)
    plt.show()

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  706.000000          706.000000        706.000000       706.000000
# mean    18.192635           18.882436          6.410765         3.890935
# std     10.927472            8.482877          3.404811         1.425503
# min      1.000000            0.000000          0.000000         2.000000
# 25%     10.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.750000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  706.000000              706.000000                       706.000000
# mean     2.549575              222.977337                        29.297450
# std      1.121527               67.293426                        14.706661
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 706 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               706 non-null    int64
#  1   Reason for absence               706 non-null    int64
#  2   Month of absence                 706 non-null    int64
#  3   Day of the week                  706 non-null    int64
#  4   Seasons                          706 non-null    int64
#  5   Transportation expense           706 non-null    int64
#  6   Distance from Residence to Work  706 non-null    int64
#  7   Service time                     706 non-null    int64
#  8   Age                              706 non-null    int64
#  9   Work load Average/day            706 non-null    int64
#  10  Hit target                       706 non-null    int64
#  11  Disciplinary failure             706 non-null    int64
# ...

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
sns.heatmap(df.corr(),cmap = 'crest')
plt.show()

# %%
corr = df.corr()

corr.to_csv('corr.csv')

# %%
df1 = df.copy()
df1.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
df1['Age'].unique()
# Out:
# array([33, 50, 38, 39, 28, 36, 34, 37, 41, 47, 29, 48, 32, 27, 43, 40, 31,
#        30, 49, 58, 46, 53], dtype=int64)

# %%
df1['Hit target'].map({97:1,92:2,93:3})
df1['Hit target'].unique()
# Out:
# array([ 97,  92,  93,  95,  99,  96,  94,  98,  81,  88, 100,  87,  91],
#       dtype=int64)

# %%
sns.scatterplot(y = 'Absenteeism time in hours',x = 'Reason for absence', data = df1,hue = 'Age' )
# Out:
# <AxesSubplot: xlabel='Reason for absence', ylabel='Absenteeism time in hours'>

# %%
sns.scatterplot(y = 'Absenteeism time in hours',x = 'Distance from Residence to Work', data = df1,hue = 'Age' )
# Out:
# <AxesSubplot: xlabel='Distance from Residence to Work', ylabel='Absenteeism time in hours'>

# %%
sns.boxplot(y = 'Age',x = 'Social drinker', data = df1 )
# Out:
# <AxesSubplot: xlabel='Social drinker', ylabel='Age'>

# %%
sns.scatterplot(y = 'Age',x = 'Reason for absence',data = df1)
# Out:
# <AxesSubplot: xlabel='Reason for absence', ylabel='Age'>

# %%
sns.histplot(x = 'Reason for absence',bins = 25,data = df1,kde = True)
# Out:
# <AxesSubplot: xlabel='Reason for absence', ylabel='Count'>

# %%
sns.barplot(x = 'Absenteeism time in hours',y = 'Hit target', data = df1,hue = 'Disciplinary failure')
# Out:
# <AxesSubplot: xlabel='Absenteeism time in hours', ylabel='Hit target'>

# %%
sns.barplot(x=np.arange(0,13) ,y = df1.groupby('Month of absence')['Month of absence'].count())
plt.xlabel('Months of absence')
plt.ylabel('No. of Employees')
# Out:
# Text(0, 0.5, 'No. of Employees')

# %%
sns.countplot(x = df1['Month of absence'])
plt.xlabel('Months of absence')
plt.ylabel('No. of Employees')
# Out:
# Text(0, 0.5, 'No. of Employees')

# %%
df1.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
sns.countplot(x = df1['Education'])
# Out:
# <AxesSubplot: xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(25,15))
sns.countplot(x = df1['Transportation expense'])
# Out:
# <AxesSubplot: xlabel='Transportation expense', ylabel='count'>

# %%
df1.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
# if hours of absentisim is less than 7, then its fine,otherwise it is not acceptable

# %%
df1['Absenteeism time in hours'] = df1['Absenteeism time in hours'].apply(lambda x:0 if x >=7 else 1)
df1['Absenteeism time in hours'].value_counts()
# Out:
# 1    435
# 0    271
# Name: Absenteeism time in hours, dtype: int64

# %%
df1['Absenteeism time in hours'].value_counts()/len(df1['Absenteeism time in hours'])*100
# Out:
# 1    61.614731
# 0    38.385269
# Name: Absenteeism time in hours, dtype: float64

# %%
#Scaling the data by using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
df_scaled = sc.fit_transform(df1.drop(columns = ['Absenteeism time in hours','ID']))
df_scaled
# Out:
# array([[ 0.8396455 ,  0.17318229, -0.62543981, ...,  0.85536465,
#         -0.03290573,  0.79118362],
#        [-2.22752522,  0.17318229, -0.62543981, ...,  1.47776861,
#          0.94184018,  1.02637336],
#        [ 0.48574119,  0.17318229,  0.07656417, ...,  0.77756415,
#         -0.35782103,  1.02637336],
#        ...,
#        [-2.22752522, -1.88418996, -0.62543981, ...,  1.47776861,
#         -0.35782103,  1.73194259],
#        [-2.22752522, -1.88418996,  0.07656417, ...,  1.6333696 ,
#         -0.35782103,  1.96713233],
#        [-2.22752522, -1.88418996,  1.48057214, ..., -0.15604179,
#          0.45446723, -0.38476509]])

# %%
df_scaled = pd.DataFrame(df_scaled, columns = (df1.drop(columns = ['Absenteeism time in hours','ID']).columns))
df_scaled
# Out:
#      Reason for absence  Month of absence  Day of the week   Seasons  \
# 0              0.839646          0.173182        -0.625440 -1.382645
# 1             -2.227525          0.173182        -0.625440 -1.382645
# 2              0.485741          0.173182         0.076564 -1.382645
# 3             -1.401748          0.173182         0.778568 -1.382645
# 4              0.485741          0.173182         0.778568 -1.382645
# 5              0.485741          0.173182         1.480572 -1.382645
# 6              0.367773          0.173182         1.480572 -1.382645
# 7              0.485741          0.173182         1.480572 -1.382645
# 8              0.013869          0.173182        -1.327444 -1.382645
# 9              0.367773          0.173182        -1.327444 -1.382645
# 10            -2.109557          0.173182        -1.327444 -1.382645
# 11            -2.109557          0.173182        -0.625440 -1.382645
# 12            -0.929876          0.173182         0.076564 -1.382645
# ...

# %%
x = df_scaled
y = df1['Absenteeism time in hours']

# %%
x.head()
# Out:
#    Reason for absence  Month of absence  Day of the week   Seasons  \
# 0            0.839646          0.173182        -0.625440 -1.382645
# 1           -2.227525          0.173182        -0.625440 -1.382645
# 2            0.485741          0.173182         0.076564 -1.382645
# 3           -1.401748          0.173182         0.778568 -1.382645
# 4            0.485741          0.173182         0.778568 -1.382645
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                0.981812                         0.456072      0.115466
# 1               -1.561100                        -1.108954      1.260392
# 2               -0.653979                         1.476741      1.260392
# 3                0.833103                        -1.653311      0.344451
# 4                0.981812                         0.456072      0.115466
#
#         Age  Work load Average/day   Hit target  Disciplinary failure  \
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Absenteeism time in hours, dtype: int64

# %%
#Model training

# %%
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest = train_test_split(x,y,test_size = 0.25)

# %%
print(xTrain.shape)
print(xTest.shape)
print(yTrain.shape)
print(yTest.shape)
# Out:
# (529, 19)
# (177, 19)
# (529,)
# (177,)

# %%
from sklearn.metrics import accuracy_score

# %%
#Build clustering and classification

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(xTrain,yTrain)
predict1 = lr.predict(xTest)
acc1 = accuracy_score(predict1,yTest)

#DecisionTree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(xTrain,yTrain)
predict2 = dt.predict(xTest)
acc2 = accuracy_score(predict2,yTest)

#RandomForest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(xTrain,yTrain)
predict3 = rf.predict(xTest)
acc3 = accuracy_score(predict3,yTest)

#SVM
from sklearn.svm import SVC
svc = SVC()
svc.fit(xTrain,yTrain)
predict4 = svc.predict(xTest)
acc4 = accuracy_score(predict4,yTest)

print('Logistic Regression: ',acc1)
print('Decision Tree: ',acc2)
print('Random Forest: ',acc3)
print('SVM: ',acc4)
# Out:
# Logistic Regression:  0.7853107344632768
# Decision Tree:  0.7740112994350282
# Random Forest:  0.8192090395480226
# SVM:  0.7853107344632768

# %%
from sklearn.ensemble import VotingClassifier

# %%
vc = VotingClassifier(estimators = [('lr',lr),('dt',dt),('rf',rf),('svm',svc)],flatten_transform=True,verbose = True)

# %%
vc.fit(xTrain,yTrain)
pred5 = vc.predict(xTest)
acc5 = accuracy_score(yTest,pred5)
# Out:
# [Voting] ....................... (1 of 4) Processing lr, total=   0.0s
# [Voting] ....................... (2 of 4) Processing dt, total=   0.0s
# [Voting] ....................... (3 of 4) Processing rf, total=   0.2s
# [Voting] ...................... (4 of 4) Processing svm, total=   0.0s

# %%
acc5
# Out:
# 0.8305084745762712

# %%
pre1_lr = lr.predict(xTrain)
train_acclr = accuracy_score(pre1_lr,yTrain)

pre1_rf = rf.predict(xTrain)
train_accrf = accuracy_score(pre1_rf,yTrain)
pre1_svc = svc.predict(xTrain)
train_accsvc = accuracy_score(pre1_svc,yTrain)
pre1_vc = vc.predict(xTrain)
train_accvc = accuracy_score(pre1_vc,yTrain)

# %%
print(acc1)
print(train_acclr)
print('**************'*5)
print(acc3)
print(train_accrf)
print('**************'*5)
print(acc4)
print(train_accsvc)
print('**************'*5)
print(acc5)
print(train_accvc)
print('**************'*5)
# Out:
# 0.7853107344632768
# 0.7523629489603024
# **********************************************************************
# 0.8192090395480226
# 0.994328922495274
# **********************************************************************
# 0.7853107344632768
# 0.8468809073724007
# **********************************************************************
# 0.8305084745762712
# 0.943289224952741
# **********************************************************************

# %%
#DecisionTree
dt = DecisionTreeClassifier()
dt.fit(xTrain,yTrain)
pre_train = dt.predict(xTrain)
pre_test = dt.predict(xTest)
print(accuracy_score(pre_train,yTrain))
print(accuracy_score(pre_test,yTest))
# Out:
# 0.994328922495274
# 0.7740112994350282

# %%
#HyperParameter tuning for decisionTree

# %%
from sklearn.pipeline import make_pipeline

# %%
pip = make_pipeline(DecisionTreeClassifier()) #RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
print(x.shape)
print(y.shape)
print(xTrain.shape)
print(yTrain.shape)
# Out:
# (706, 19)
# (706,)
# (529, 19)
# (529,)

# %%
param = {'criterion':['gini','entropy'],'max_depth':list(range(0,105,5)),'max_leaf_nodes':list(range(0,105,5)),'min_impurity_decrease': list(range(0,105,5)) }
#param = {'DecisionTreeClassifier_max_depth':list(range(5,105,5))}
param1 = {'criterion':['gini','entropy'],'max_depth':list(range(0,105,5)),'max_leaf_nodes':list(range(0,105,5))}

# %%
gs = GridSearchCV(DecisionTreeClassifier(),cv = 5,param_grid = param1,verbose = True)
gs.fit(x,y)
gs.best_score_
# Out:
# Fitting 5 folds for each of 882 candidates, totalling 4410 fits
# 0.81579262810908

# %%
gs.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=75)

# %%
dt = DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=45)
dt.fit(xTrain,yTrain)
pre_train = dt.predict(xTrain)
pre_test = dt.predict(xTest)
print(accuracy_score(pre_train,yTrain))
print(accuracy_score(pre_test,yTest))
# Out:
# 0.8525519848771267
# 0.7966101694915254
